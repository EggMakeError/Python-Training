# %%
import pandas as pd

url = 'https://drive.google.com/file/d/1ACHWXEnL9TxNWjrtWpxszV29YrJDNWa2/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands_df = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1x6BI5Bsb-mLFO-O_gct7WF5UbU4s90Py/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines_df = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1oHwUzohlDAT161sfzjX5WVQfIZ1ZLQRd/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders_df = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1_7_0FUsjfKcyaCBfZlhrmNTctACf_6ob/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products_df = pd.read_csv(path)

# %% [markdown]
# # Data Exploration Section

# %%
print(brands_df.head())
# Out:
#   short       long
# 0   8MO  8Mobility
# 1   ACM       Acme
# 2   ADN     Adonit
# 3   AII      Aiino
# 4   AKI     Akitio

# %%
print(orderlines_df.head())
# Out:
#         id  id_order  product_quantity      sku unit_price  \
# 0  1119109    299539                 1  OTT0133      18.99
# 1  1119110    299540                 1  LGE0043     399.00
# 2  1119111    299541                 1  PAR0071     474.05
# 3  1119112    299542                 1  WDT0315      68.39
# 4  1119113    299543                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %%
print(orders_df.head())
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled

# %%
print(products_df.head(20))
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99     499.899
# 1           USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                              mouse Apple USB cable.     59     569.898
# 3               IPhone dock and USB Cable Apple iPod.     25     229.997
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# 5   IPhone and iPod AV Cable Dock to Composite Video.     45     420.003
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99     146.471
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99     274.694
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...     74     669.904
# 9   Adapter Mini Display Port to VGA MacBook and M...     35     330.003
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...     35     330.003
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99     449.878
# 12                       USB to Ethernet adapter Mac.     35     330.003
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).     89     849.904
# 14           FireWire 400 adapter cable FireWire 800.     20     179.891
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95     249.889
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...     89     849.904
# 17  Dock and support with multiple connections for...  69.99     699.864
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99       7.986
# 19                         Dock Connector to VGA IOS.     35     350.005
#
#     in_stock      type
# 0          1      8696
# 1          0  13855401
# 2          0      1387
# 3          0      1230
# 4          1      1364
# 5          0      1230
# 6          0      1364
# 7          0      1364
# 8          0      1364
# 9          0      1325
# 10         0      1325
# 11         0      5384
# 12         0      1334
# 13         0  13005399
# 14         0      1325
# 15         0  13835403
# 16         1  13005399
# 17         0  12995397
# 18         0  11865403
# 19         0  13955395

# %%
print(brands_df.info())
products_df['type'] = pd.to_numeric(products_df['type'], errors='coerce')
products_df.loc[products_df['type'] == 1364]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB
# None
#              sku                                               name  \
# 4        KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 6        KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7        KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8      KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 29       KIN0025          Mac memory DIMM DDR3 2GB 1333MHz Kingston
# ...          ...                                                ...
# 17544    OWC0253                Mac OWC Memory 2GB DDR2 533MHz DIMM
# 17545    OWC0254             Mac OWC Memory 1GB 667MHz DDR2 FB-DIMM
# 17946    PAC2192  Kit OWC expansion RAM 16GB (2x8GB) DDR4 iMac 2...
# 17947    PAC2193  Kit OWC expansion RAM 32GB (2x16GB) DDR4 iMac ...
# 18664    OWC0199                    Memory DIMM 4GB 1866MHz OWC Mac
#
#                                                     desc   price  promo_price  \
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...   34.99        31.99
# 6      1GB RAM Mac mini and iMac (2006/07) MacBook Pr...   18.99        14.65
# 7           2GB RAM iMac with Intel Core 2 Duo (Penryn).   36.99        27.47
# 8      RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...      74        66.99
# 29                          2GB RAM Mac Pro (July 2010).   29.99        17.99
# ...                                                  ...     ...          ...
# 17544                     RAM 1GB iMac G5 / PowerMac G5.   22.99        22.99
# 17545                  1GB RAM for Mac Pro 2006 and 2007   22.99        22.99
# 17946    Tool kit + OWC RAM 16GB DDR4 215 inch iMac 2017  275.97       264.99
# 17947    Tool kit + OWC RAM 32GB DDR4 215 inch iMac 2017  475.97          NaN
# 18664                              RAM 4GB Mac Pro 2013.   48.99        44.99
#
#        in_stock    type
# 4             1  1364.0
# 6             0  1364.0
# 7             0  1364.0
# 8             0  1364.0
# 29            0  1364.0
# ...         ...     ...
# 17544         1  1364.0
# 17545         0  1364.0
# 17946         0  1364.0
# 17947         0  1364.0
# 18664         1  1364.0
#
# [220 rows x 7 columns]

# %%
print(orderlines_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_quantity  293983 non-null  int64
#  3   sku               293983 non-null  object
#  4   unit_price        293983 non-null  object
#  5   date              293983 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 13.5+ MB
# None

# %%
print(orders_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB
# None

# %%
print(products_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB
# None

# %%
print(brands_df.describe())

# there are 187 unique short abbreviations for the companies but only 181 unique names for companies, so some of the names for the companies got duplicated onto the abbreviations from other companies.
# Out:
#        short    long
# count    187     187
# unique   187     181
# top      8MO  Mophie
# freq       1       2

# %%
print(orderlines_df.describe())
# Out:
#                  id       id_order  product_quantity
# count  2.939830e+05  293983.000000     293983.000000
# mean   1.397918e+06  419999.116544          1.121126
# std    1.530096e+05   66344.486479          3.396569
# min    1.119109e+06  241319.000000          1.000000
# 25%    1.262542e+06  362258.500000          1.000000
# 50%    1.406940e+06  425956.000000          1.000000
# 75%    1.531322e+06  478657.000000          1.000000
# max    1.650203e+06  527401.000000        999.000000

# %%
print(orders_df.describe())
# Out:
#             order_id     total_paid
# count  226909.000000  226904.000000
# mean   413296.482480     569.225818
# std     65919.250331    1761.778002
# min    241319.000000       0.000000
# 25%    356263.000000      34.190000
# 50%    413040.000000     112.990000
# 75%    470553.000000     525.980000
# max    527401.000000  214747.530000

# %%
print(products_df.describe())
# Out:
#            in_stock
# count  19326.000000
# mean       0.109593
# std        0.312390
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
orders_df.duplicated().any()
# Out:
# False

# %%
brands_df.duplicated().any()
# Out:
# False

# %%
orderlines_df.duplicated().any()
# Out:
# False

# %%
products_df.duplicated().any()
# Out:
# True

# %%
# Out:
#         order_id         created_date  total_paid    state
# 127701    427314  2017-11-20 18:54:39         NaN  Pending
# 132013    431655  2017-11-22 12:15:24         NaN  Pending
# 147316    447411  2017-11-27 10:32:37         NaN  Pending
# 148833    448966  2017-11-27 18:54:15         NaN  Pending
# 149434    449596  2017-11-27 21:52:08         NaN  Pending

# %% [markdown]
# # Data Cleaning Section

# %% [markdown]
# **orders_df cleaning**

# %% [markdown]
# **orderlines_df cleaning**

# %% [markdown]
# **products_df cleaning**

# %%
# we will start by dropping columns that contain no data

orderlines_df.drop(columns=['product_id'], inplace=True)

# %%
# next I want to rename the id_order column from orders_df to order_id so it matches up with orderlines_df

orderlines_df = orderlines_df.rename(columns={'id_order': 'order_id'})

# %%
# in orders_df there are 5 lines missing a value for "total_paid", we are going to locate those 5 to assign a value

missing_total_paid = orders_df.loc[orders_df['total_paid'].isna()]

# first, lets take a look at these lines to better understand the structure and also to see the common denominator which we can use to find the actual item value
print(missing_total_paid)

# we want to find out which items are assigned to the order_id
# Out:
#         order_id         created_date  total_paid    state
# 127701    427314  2017-11-20 18:54:39         NaN  Pending
# 132013    431655  2017-11-22 12:15:24         NaN  Pending
# 147316    447411  2017-11-27 10:32:37         NaN  Pending
# 148833    448966  2017-11-27 18:54:15         NaN  Pending
# 149434    449596  2017-11-27 21:52:08         NaN  Pending

# %%
# date in orders_df is an object but should be converted to datetime format

orders_df['created_date'] = pd.to_datetime(orders_df['created_date'])

# %%
# lets do the same for the 'date' column in orderlines_df

orderlines_df['date'] = pd.to_datetime(orderlines_df['date'])

# %%
# in order to convert the object type of the unit_price column in orderlines_df to numeric, we have to first drop the additional decimal points in line 6

orderlines_df['unit_price'] = orderlines_df['unit_price'].str.replace(r'(?<=\d)\.(?=.*\.)', '', regex=True)

# %%
# Convert to numeric so we can work with it later on

orderlines_df['unit_price'] = pd.to_numeric(orderlines_df['unit_price'], errors='coerce')

# %%
products_df['promo_price'] = pd.to_numeric(products_df['promo_price'], errors='coerce')

products_df['promo_price'] = products_df['promo_price'] / 10

# Step 2: Round the promo_price column to 2 decimal places
products_df['promo_price'] = products_df['promo_price'].round(2)

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  float64
#  6   date              293983 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 15.7+ MB

# %%
# in this step, we identify the rows with three decimal places (using regex)
mask_three_decimals = products_df['promo_price'].str.contains(r'\.\d{3}$', na=False)

# now we convert 'promo_price' to float for all rows with three decimals
products_df.loc[mask_three_decimals, 'promo_price'] = pd.to_numeric(products_df.loc[mask_three_decimals, 'promo_price'], errors='coerce')

# Adjusting only the rows with three decimals, using the filter mask we created
products_df.loc[mask_three_decimals, 'promo_price'] = (products_df.loc[mask_three_decimals, 'promo_price'] / 10).round(2)

# and now we convert all the values in 'promo_price' to numeric (in this case float64)
products_df['promo_price'] = pd.to_numeric(products_df['promo_price'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-4e8fc6c89240> in <cell line: 2>()
#       1 # in this step, we identify the rows with three decimal places (using regex)
# ----> 2 mask_three_decimals = products_df['promo_price'].str.contains(r'\.\d{3}$', na=False)
#       3
#       4 # now we convert 'promo_price' to float for all rows with three decimals
#       5 products_df.loc[mask_three_decimals, 'promo_price'] = pd.to_numeric(products_df.loc[mask_three_decimals, 'promo_price'], errors='coerce')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     189         from pandas.core.arrays.string_ import StringDtype
#     190
# --> 191         self._inferred_dtype = self._validate(data)
#     192         self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     243
#     244         if inferred_dtype not in allowed_types:
# --> 245             raise AttributeError("Can only use .str accessor with string values!")
#     246         return inferred_dtype
#     247
#
# AttributeError: Can only use .str accessor with string values!

# %%
# we are creating a filter to apply to the dataframe filtering all the promo_price values that are higher than the initial price (because a promotion price should be lower than the initial price)

mask_promo_higher =  pd.to_numeric(products_df['promo_price'], errors='coerce') > pd.to_numeric(products_df['price'], errors='coerce')

# we are locating all the lines that adhere to our filter without touching the values that are already lower than the initial price (using pd.to_numeric to only change the "object" type of the filtered values to float64 ensuring that the values that are correct, don't get touched)

products_df.loc[mask_promo_higher, 'promo_price'] = pd.to_numeric(products_df.loc[mask_promo_higher, 'promo_price'], errors='coerce')

# we are now applying a calculation to these located lines because what I think happened is that instead of a discount, they applied the discount value as a multiplier (i.e. instead of multiplying with 0.82, they multiplied with 8.2 because the decimal point was not at the correct location)

products_df.loc[mask_promo_higher, 'promo_price'] = (products_df.loc[mask_promo_higher, 'promo_price'] / 10).round(2)

# and now we convert all the values in 'promo_price' to numeric (in this case float64)
products_df['promo_price'] = pd.to_numeric(products_df['promo_price'], errors='coerce')

# %%
# rounding the last 2 digits in each line so it shows a decimal point

products_df['promo_price'] = products_df['promo_price'].round(2)

# %%
print(products_df)
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99        49.99
# 1              USB ultrathin keyboard Apple Mac Spanish.     59        59.00
# 2                                 mouse Apple USB cable.     59        56.99
# 3                  IPhone dock and USB Cable Apple iPod.     25        23.00
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# ...                                                  ...    ...          ...
# 19321  compact and portable stand vertically or horiz...  29.99        26.99
# 19322  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19323  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19324  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19325  Backpack with capacity of 14 liter compartment...  69.95        64.99
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [19326 rows x 7 columns]

# %%
missing_values_price = products_df.loc[products_df['price'].isna()]
print(missing_values_price)
# Out:
#              sku                                               name  \
# 34       TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 1900     AII0008           Aiino Case MacBook Air 11 '' Transparent
# 2039     CEL0020  Celly Ambo Luxury Leather Case + iPhone 6 Case...
# 2042     CEL0007  Celly Wallet Case with removable cover Black i...
# 2043     CEL0012            Celly Silicone Hard Shell iPhone 6 Blue
# 2044     CEL0014        Celly Silicone Hard Shell iPhone 6 Amarillo
# 2049     CEL0015    Celly fur-lined Powerbank battery 4000mAh Black
# 2051     CEL0018     Celly Wallet Leather Case cover Black iPhone 6
# 2052     CEL0023  Celly Ambo Luxury Leather Case + Case Gold iPh...
# 2053     CEL0025  Celly Ambo Luxury Leather Case + Case iPhone 6...
# 8000     APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
# 12052    CEL0028  Celly Swing Arm button selfie with Bluetooth B...
# 12053    CEL0029  Celly extensible arm selfie with Bluetooth but...
# 12054    CEL0030  Celly Smart Drive Housing + clip car holder iP...
# 12055    CEL0031  Celly Smart Drive Case + Car clip support iPho...
# 12059    CEL0032      Celly Gost clamp fixing car + Magnetica Black
# 12060    CEL0042  Celly iPhone Case Fluor 6s / 6 Black / Transpa...
# 12061    CEL0043  Celly Fluor Case iPhone 6 / 6S Pink / Transparent
# 12062    CEL0044  Celly iPhone Case Fluor 6s / 6 Yellow / Transp...
# 12064    CEL0038           Celly Frost Cover for iPhone 6 / 6S Rosa
# 12067    CEL0033  Celly Waterproof iPad Case / Air / Pro 97 "Tra...
# 12068    CEL0034  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12069    CEL0035  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12070    CEL0036  Celly Adapter Micro USB connector to Lightning...
# 12071    CEL0051   Celly 4000mAh Battery Power Bank Aluminum Dorado
# 12072    CEL0052   Celly 4000mAh Battery Power Bank Aluminum Silver
