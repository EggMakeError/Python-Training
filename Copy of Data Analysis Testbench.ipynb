# %%
import pandas as pd

url = 'https://drive.google.com/file/d/1NdBi3GPnxAboqLMlF6JXLGi1PrliCpac/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands_cl = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1V4zxd9DkFph7HrThDfuiHVDtkIvMK7aI/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines_cl = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1M2IXTLWG80C5D_TLHp1A7HydUPBUdCqD/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders_cl = pd.read_csv(path)

url = 'https://drive.google.com/file/d/1SaSDac7JgYc3vNBV87SpFlUNfoQMdH8Y/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products_cl = pd.read_csv(path)

# %%
brands_df = brands_cl.copy()
orderlines_df = orderlines_cl.copy()
orders_df = orders_cl.copy()
products_df = products_cl.copy()

# %%
orderlines_df.head()

# %%
products_df.isna().sum()
# Out:
# sku              0
# name           101
# desc           101
# price            0
# promo_price      0
# in_stock         0
# type           997
# dtype: int64

# %%
products_df.head(20)
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price  promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99        49.99
# 1           USB ultrathin keyboard Apple Mac Spanish.  59.00        59.00
# 2                              mouse Apple USB cable.  59.00        56.99
# 3               IPhone dock and USB Cable Apple iPod.  25.00        23.00
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# 5   IPhone and iPod AV Cable Dock to Composite Video.  45.00        42.00
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99        14.65
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99        27.47
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...  74.00        66.99
# 9   Adapter Mini Display Port to VGA MacBook and M...  35.00        33.00
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...  35.00        33.00
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99        44.99
# 12                       USB to Ethernet adapter Mac.  35.00        33.00
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).  89.00        84.99
# 14           FireWire 400 adapter cable FireWire 800.  20.00        17.99
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95        24.99
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...  89.00        84.99
# 17  Dock and support with multiple connections for...  69.99        69.99
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99         7.99
# 19                         Dock Connector to VGA IOS.  35.00        35.00
#
#     in_stock        type
# 0          1      8696.0
# 1          0  13855401.0
# 2          0      1387.0
# 3          0      1230.0
# 4          1      1364.0
# 5          0      1230.0
# 6          0      1364.0
# 7          0      1364.0
# 8          0      1364.0
# 9          0      1325.0
# 10         0      1325.0
# 11         0      5384.0
# 12         0      1334.0
# 13         0  13005399.0
# 14         0      1325.0
# 15         0  13835403.0
# 16         1  13005399.0
# 17         0  12995397.0
# 18         0  11865403.0
# 19         0  13955395.0

# %%
filtered_df = products_df.loc[products_df['type_last_4'] == '5397']
print(filtered_df.to_string())
# Out:
#              sku                                                                                            name                                                                                                                                                  desc     price  promo_price  in_stock        type type_last_4                category            deviations
# 17       HGD0007                                                    Henge Docks Docking Station MacBook Pro 13 "                                                                                   Dock and support with multiple connections for MacBook Pro 13-inch.     69.99        69.99         0  12995397.0        5397  Data Storage Solutions                    []
# 64       LAC0141                                         LaCie Porsche Design 1TB External Hard Drive Mac and PC                                                                                                            External Hard Drive Mac and PC USB 3.0 1TB     79.99        77.79         0  11935397.0        5397  Data Storage Solutions                    []
# 71       SEA0039                                            Seagate Barracuda 2TB 35 "SATA hard drive Mac and PC                                                                                                      Internal Hard Drive 2TB Mac and PC (ST2000DM006)     89.99        63.99         1  12655397.0        5397  Data Storage Solutions                    []
# 78       SEA0044                                            Seagate Barracuda 3TB 35 "SATA hard drive Mac and PC                                                                                                     internal hard drive Mac and PC 3TB (ST3000DM008).    112.00        84.90         1  12655397.0        5397  Data Storage Solutions                    []
# 82       WDT0127                                      Western Digital Green 1TB 35 "5400pm hard drive Mac and PC                                                                                                     WD Internal Hard Drive Mac and PC 1TB (WD10EZRX).     65.00        55.49         0  12655397.0        5397  Data Storage Solutions                    []
# 83       OTR0045                                         External Slim Case for SuperDrive MacBook / MacBook Pro                                                                                                 External SuperDrive case for MacBook and MacBook Pro.     35.00        29.99         1  12995397.0        5397  Data Storage Solutions                    []
# 99       SEA0049                                        Seagate Barracuda 1TB Hard Drive 35 "SATA for Mac and PC                                                                                                      internal hard drive Mac and PC 1TB (ST1000DM010)     59.00        41.20         1  12655397.0        5397  Data Storage Solutions                    []
# 122      SNN0016                                                                         Sonnet XMAC mini Server                                                                                                                 Turn your Mac mini Server Rack format   1208.79      1099.99         0  12175397.0        5397  Data Storage Solutions                    []
# 134      DLK0011                                         D-Link DUB-1340 Hub 4 x SuperSpeed ​​USB 3.0 Mac and PC                                                                                                                      Dlink USB Hub Mac and PC 4 port.     64.00        46.99         0  12995397.0        5397  Data Storage Solutions                    []
# 135      DLK0012                                                 D-Link DUB-H7 Hub 7 x Hi-Speed ​​USB Mac and PC                                                                                                                     Dlink USB Hub Mac and PC 7 ports.     33.99        26.99         0  12995397.0        5397  Data Storage Solutions                    []
# 137      WDT0139                                                        Red 1TB WD 35 "Mac PC hard drive and NAS                                                                                           Western Digital hard drive designed for NAS 1TB (WD10EFRX).     77.00        64.49         0  12655397.0        5397  Data Storage Solutions                    []
# 138      WDT0140                                                        Red 2TB WD 35 "Mac PC hard drive and NAS                                                                                           Western Digital hard drive designed for NAS 2TB (WD20EFRX).     99.00        80.59         1  12655397.0        5397  Data Storage Solutions                    []
# 139      WDT0141                                                        WD Red 3TB 35 "Mac PC hard drive and NAS                                                                                           Western Digital hard drive designed for NAS 3TB (WD30EFRX).    129.00       101.99         1  12655397.0        5397  Data Storage Solutions                    []
# 140      WDT0183                                                        Red 4TB WD 35 "Mac PC hard drive and NAS                                                                                           Western Digital hard drive designed for NAS 4TB (WD40EFRX).    169.00       125.99         1  12655397.0        5397  Data Storage Solutions                    []
# 141      WDT0249                                                        WD Red 6TB 35 "Mac PC hard drive and NAS                                                                                           Western Digital hard drive designed for NAS 6TB (WD60EFRX).    255.00       189.99         1  12655397.0        5397  Data Storage Solutions                    []
# 142      WDT0318                                                        WD Red 8TB 35 "Mac PC hard drive and NAS                                                                   Western Digital Hard Drive 8TB 35 inch SATA 6 Gb / s for small businesses and home.    359.00       239.99         1  12655397.0        5397  Data Storage Solutions                    []
# 143      WDT0395                                                       WD Red 10TB 35 "Mac PC hard drive and NAS                                                                  Western Digital Hard Drive 10TB 35-inch SATA 6 Gb / s for small businesses and home.    439.00       339.99         1  12655397.0        5397  Data Storage Solutions                    []
# 145      SAN0013                                                    SanDisk Cruzer Blade 8GB USB 2.0 Flash Drive                                                                                                           Compact flash drive 8GB USB 2.0 Mac and PC.      4.00         3.99         0  57445397.0        5397  Data Storage Solutions                    []
# 146      SAN0014                                                   SanDisk Cruzer Blade 16GB USB 2.0 Flash Drive                                                                                                          Compact flash drive 16GB USB 2.0 Mac and PC.      6.00         4.99         0  57445397.0        5397  Data Storage Solutions                    []
# 147      SAN0017                                                    SanDisk Cruzer Edge USB 2.0 Flash Drive 16GB                                                                                                                          Pendrive USB 2.0 Mac and PC.      8.00         5.99         0         NaN        5397  Data Storage Solutions                    []
# 149      NTE0011                                                            NewerTech miniStack external box Mac                                                                                                   Mac external box 35 USB 3.0 eSATA FireWire 800/400.    108.99        89.99         0  12995397.0        5397  Data Storage Solutions                    []
# 150      OWC0020                                            Envoy OWC USB 3.0 Case for MacBook Air SSD 2010/2011                                                                                              Box Portable External USB 2.0 / 3.0 for MacBook Air SSD.     60.99        41.99         1  11935397.0        5397  Data Storage Solutions                    []
# 167      OWC0037                                OWC Mercury Elite Pro Mini aluminum box 25 "FW800 / USB2 / eSATA                                                                                              outer case 25 inch SATA eSATA / FW800 / FW400 / USB 2.0.     69.99         7.49         0  12995397.0        5397  Data Storage Solutions                    []
# 173      OWC0025                            SSD expansion kit OWC Aura Pro 6G 240GB MacBook Air 11 "and 13" 2012                                                                                SSD 240GB expansion for MacBook Air 11-inch and 13-inch 2012 Kit tools    241.99       199.58         1  12215397.0        5397  Data Storage Solutions                    []
# 175      OWC0009                                OWC Case External SuperSlim for SuperDrive MacBook / MacBook Pro                                                                                                             Black External Case for Apple SuperDrive.     48.99        20.49         1  11935397.0        5397  Data Storage Solutions                    []
# 176      OWC0039                         OWC Mercury On-The-Go Pro Mini transparent box 25 "FW800 / FW400 / USB3                                                                                           outer case 25 inch SATA connection FW800 / FW400 / USB 3.0.     96.99        69.99         1  11935397.0        5397  Data Storage Solutions                    []
# 177      OWC0040                                  OWC Mercury On-The-Go Pro Mini transparent box 25 "USB3 / USB2                                                                                                              outer case 25 inch SATA USB 3.0 and 2.0.     54.99        32.99         1  11935397.0        5397  Data Storage Solutions                    []
# 179      OWC0016                                             OWC Aura Pro 6G 240GB SSD for MacBook Air 2010-2011                                                                                240GB SSD hard drive for MacBook Air 2010/2011 + tools + external box.    199.99       196.58         0  12215397.0        5397  Data Storage Solutions                    []
# 180      OWC0015                        OWC Aura expansion kit 6G SSD 120GB MacBook Air 11 "and 13" 2010 to 2011                                                               120GB SSD expansion for MacBook Air 11-inch and 13-inch Late 2010 to Mid 2011 Kit tools    144.99       131.58         1  12215397.0        5397  Data Storage Solutions                    []
# 227      SYN0063                                                         Synology DX513 expansion NAS Mac and PC                                                                                                                                Expansion unit 5 bays.    423.99       423.90         0  12175397.0        5397  Data Storage Solutions                    []
# 246      PAC0272                                        OWC Mercury On-The-Go Pro Mini 1TB Hard Drive Mac and PC                                                                                   Pack outer case 25 inch connections FW800 / FW400 / USB3 + HDD 1TB.    159.98       122.59         1  11935397.0        5397  Data Storage Solutions                    []
# 247      PAC0271                                        OWC Mercury On-The-Go Pro Mini Hard Drive 1TB Mac and PC                                                                                                    Pack outer box 25 inches + 1TB Hard Drive USB 3.0.    184.98        85.58         1  11935397.0        5397  Data Storage Solutions                    []
# 248      PAC0273                                                          NewerTech miniStack 1TB Hard Drive Mac                                                                                                                    External box Mac + 1TB Hard Drive.    148.99       135.99         0  11935397.0        5397  Data Storage Solutions                    []
# 249      PAC0274                                                          NewerTech miniStack Mac 2TB Hard Drive                                                                                                                    External box Mac + 2TB Hard Drive.    179.98       157.99         0  11935397.0        5397  Data Storage Solutions                    []
# 250      PAC0275                                                          NewerTech miniStack 3TB Hard Drive Mac                                                                                                                           Mac external box 3TB + HDD.    201.99       179.99         0  11935397.0        5397  Data Storage Solutions                    []
# 251      KIN0074                                                       Kingston DataTraveler SE9 8GB USB 2.0 key                                                                                                                    8GB USB 2.0 key minimalist design.      4.99         5.78         0  57445397.0        5397  Data Storage Solutions                    []
# 252      KIN0072                                                      Kingston DataTraveler SE9 16GB USB 2.0 key                                                                                                                   16GB USB 2.0 key minimalist design.      7.00         6.28         0  57445397.0        5397  Data Storage Solutions                    []
# 253      KIN0073                                                      Kingston DataTraveler SE9 32GB USB 2.0 key                                                                                                                   32GB USB 2.0 key minimalist design.     14.99        14.28         0  57445397.0        5397  Data Storage Solutions                    []
# 273      NTE0025                                       NewerTech Voyager Q HDD Dock FW800 / 400 / USB3.0 / eSATA                                                                                           Dock disc 25 inch and 35 inch FW800 / 400 / USB3.0 / eSATA.    108.99        62.69         0  12995397.0        5397  Data Storage Solutions                    []
# 274      NTE0026                                                     NewerTech Voyager S3 Dock HDD USB3.0 / Sata                                                                                                Dock disc 25 inches and 35 inches with USB3.0 / eSATA.     60.99        39.99         1  12995397.0        5397  Data Storage Solutions                    []
# 296      OWC0044                    SSD expansion kit OWC Aura Pro 6G 480GB MacBook Air 11 "and 13" 2010 to 2011                                                               480GB SSD expansion for MacBook Air 11-inch and 13-inch Late 2010 to Mid 2011 Kit tools    386.99       319.58         0  12215397.0        5397  Data Storage Solutions                    []
# 314      LMP0011                                             External Slim Case for SuperDrive iMac and Mac mini                                                                                                      external enclosure iMac SuperDrive and Mac Mini.     35.00        29.99         0  12995397.0        5397  Data Storage Solutions                    []
# 331      OWC0218                            SSD expansion kit OWC Aura Pro 6G 120GB MacBook Air 11 "and 13" 2012                                                                           120GB SSD expansion for MacBook Air 11-inch and 13-inch 2012 with Tools Kit    151.00       131.58         0  12215397.0        5397  Data Storage Solutions                    []
# 332      OWC0022                            SSD expansion kit OWC Aura Pro 6G 480GB MacBook Air 2012 11 "and 13"                                                                             480GB SSD expansion for Mid 2012 MacBook Air 11-inch and 13-inch tool kit    379.99       300.58         1  12215397.0        5397  Data Storage Solutions                    []
# 333      OWC0065        SSD expansion kit OWC Aura Pro 6G 480GB MacBook Pro Retina 13 "and 15" from 2012 to 2013               expansion of 480GB SSD for MacBook Pro Retina 13-inch Late 2012 and Early 2013 MacBook Pro Retina 15-inch Early 2013 Mid 2012 Kit tools    411.99       346.58         0  12215397.0        5397  Data Storage Solutions                    []
# 334      OWC0066        SSD expansion kit OWC Aura Pro 6G 240GB MacBook Pro Retina 13 "and 15" from 2012 to 2013                     240GB SSD expansion MacBook Pro Retina 13-inch Late 2012 and Early 2013 MacBook Pro Retina 15-inch Mid 2012 / Early 2013 Tool Kit    229.99       199.99         0  12215397.0        5397  Data Storage Solutions                    []
# 336      DRO0015                                             Drobo 5D USB 3.0 Thunderbolt Mac and PC RAID System                                                                                                            Mac and PC RAID 5-bay Thunderbolt USB 3.0.    749.00       658.99         0  11935397.0        5397  Data Storage Solutions                    []
# 337      DRO0016                                           Drobo Mini USB 3.0 Thunderbolt Mac and PC RAID System                                                                                                       Mac and PC RAID 4 bay with USB 3.0 Thunderbolt.    699.00       619.99         0  11935397.0        5397  Data Storage Solutions                    []
# 343      TOS0007                                              Toshiba 1TB 25 "SATA 5400rpm hard drive Mac and PC                                                                                            internal hard drive Mac and PC 1TB and 95 mm (MQ01ABD100).     62.99        51.99         1  12655397.0        5397  Data Storage Solutions                    []
# 370      SAN0026                                                 SanDisk Extreme Cruzer 16GB USB 3.0 Flash Drive                                                                                                              USB 3.0 flash drive 16GB USB Mac and PC.     22.00        20.99         0         NaN        5397  Data Storage Solutions                    []
# 371      SAN0028                                                    SanDisk Extreme Cruzer 64GB USB 3.0 PenDrive                                                                                                              USB Flash Drive 64GB USB 3.0 Mac and PC.     52.99        45.28         0  11935397.0        5397  Data Storage Solutions                    []
# 381      HGD0018                                                    Henge Docks Docking Station MacBook Air 11 "                                                                                      Dock with multiple functions and USB 3.0 for MacBook Air 11-inch     74.99        69.99         0  12995397.0        5397  Data Storage Solutions                    []
# 386      HGS0008                                       HGST Travelstar 1TB 25 "7200rpm hard drive Mac PC and PS4                                                                                  Mac PC internal hard drive and 25-inch PS4 and 1TB SATA III 7200rpm.     71.00        63.99         0  12655397.0        5397  Data Storage Solutions                    []
# 392      TRI0007                                                      Tribe Star Wars Yoda 8GB USB 2.0 Pen Drive                                                                                                  PenDrive 8GB USB 2.0 + 1GB online edition Star Wars.     20.28        20.28         0  57445397.0        5397  Data Storage Solutions                    []
# 393      TRI0008                                               Star Wars Darth Vader Tribe 8GB USB 2.0 Pen Drive                                                                                                  PenDrive 8GB USB 2.0 + 1GB online edition Star Wars.     19.99        19.99         0  57445397.0        5397  Data Storage Solutions                    []
# 394      TRI0009                                              Tribe Star Wars Stormtrooper 8GB USB 2.0 Pen Drive                                                                                                  PenDrive 8GB USB 2.0 + 1GB online edition Star Wars.     19.99        19.99         0  57445397.0        5397  Data Storage Solutions                    []
# 395      OWC0067                                             OWC Mercury Aura Pro SSD 60GB MacBook Air 2008/2009                                                                                                                   60GB SSD for MacBook Air 2008/2009.    126.99       106.58         0  12215397.0        5397  Data Storage Solutions                    []
# 396      OWC0018                                 OWC Mercury Aura Pro SSD 120GB MacBook Air Late 2008 - Mid 2009                                                                                                       120GB SSD for MacBook Air Late 2008 - Mid 2009.    175.99       131.58         0  12215397.0        5397  Data Storage Solutions                    []
# 397      OWC0019                                 OWC Mercury Aura Pro SSD 240GB MacBook Air Late 2008 - Mid 2009                                                                                                       240GB SSD for MacBook Air Late 2008 - Mid 2009.    241.99       194.99         0  12215397.0        5397  Data Storage Solutions                    []
# 398      OWC0072                                                                OWC Mercury Electra 6G SSD 240GB                                                                                                       240GB SSD hard drive 9.5mm SATA III Mac and PC.    164.99       136.58         0  12215397.0        5397  Data Storage Solutions                    []
# 399      OWC0123                                                            OWC Mercury Electra 6G 480GB SSD 7mm                                                                                                                SSD 480GB SATA HDD 7mm III Mac and PC.    278.99       206.58         0  12215397.0        5397  Data Storage Solutions                    []
# 400      KIN0078                                                                    Kingston V300 SSD Disk 120GB                                                                                                             SSD 120GB SATA Hard Drive Mac and PC III.     60.00         6.86         0  12215397.0        5397  Data Storage Solutions                    []
# 401      KIN0079                                                                    Kingston V300 SSD Disk 240GB                                                                                                              SSD 240GB SATA Hard Drive Mac and PC III     94.99        99.58         0  12215397.0        5397  Data Storage Solutions                    []
# 411      OWC0075                                               OWC Envoy Pro USB 3.0 Case for MacBook Pro Retina                                                                                             Box Portable External USB 3.0 SSD for MacBook Pro Retina.    118.99        59.99         0  11935397.0        5397  Data Storage Solutions                    []
# 412      TRI0012                                                 Star Wars Chewbacca Tribe 8GB USB 2.0 Pen Drive                                                                                                  PenDrive 8GB USB 2.0 + 1GB online edition Star Wars.     19.99        15.28         0  11935397.0        5397  Data Storage Solutions                    []
# 413      TRI0013                                                      C3PO Star Wars Tribe 8GB USB 2.0 Pen Drive                                                                                                  PenDrive 8GB USB 2.0 + 1GB online edition Star Wars.     19.99        16.99         0  57445397.0        5397  Data Storage Solutions                    []
# 416      SEA0052                                        Seagate 1TB SSHD Hybrid Drive 2.5 "hard drive Mac and PC                                                                            Hybrid Hard Drive Mac and PC 1TB + 8GB SSD and 95mm 5400rpm (ST1000LM014).    111.99        96.58         0  12655397.0        5397  Data Storage Solutions                    []
# 417      DRO0017                                                                  5N Drobo NAS server Mac and PC                                                                                                                         Mac and PC system RAID 5-bay.    619.00       429.99         0  11935397.0        5397  Data Storage Solutions                    []
# 429      NTE0049                                                     NewerTech miniStack MAX + DVD recorder / CD                                                                                                   Housing for Mac Mini with recorder and card reader.    235.99       187.24         1  12995397.0        5397  Data Storage Solutions                    []
# 430      NTE0050                                            NewerTech miniStack MAX + Recorder BLURAY / DVD / CD                                                                                Housing for Mac Mini with DVD and Bluray DVD recorder and card reader.    337.99       282.24         0  12995397.0        5397  Data Storage Solutions                    []
# 432      OWC0076                              OWC Mercury Elite Pro aluminum box 35 "Quad FW800 / USB3.0 / eSata                                                                                                    outer case 35 inches SATA eSATA / FW800 / USB 3.0.    120.99        99.99         1  11935397.0        5397  Data Storage Solutions                    []
# 438      OWC0078                                                  OWC Mercury PCI Express SSD 240GB Accelsior_E2                                                                                                     PCI Express Card SSD 240GB (2x128GB) for Mac Pro.    459.99       312.99         1  12215397.0        5397  Data Storage Solutions                    []
# 439      OWC0079                                                  OWC Mercury PCI Express SSD 480GB Accelsior_E2                                                                                                     PCI Express Card SSD 480GB (2x256GB) for Mac Pro.    604.99       424.99         0  12215397.0        5397  Data Storage Solutions                    []
# 440      OWC0080                                                  OWC Mercury PCI Express SSD 960GB Accelsior_E2                                                                                                     PCI Express Card SSD 960GB (2x512GB) for Mac Pro.    907.99       630.00         0  12215397.0        5397  Data Storage Solutions                    []
# 441      SEA0053                                    4TB Seagate Barracuda 35 "SATA 5900rpm hard drive Mac and PC                                                                                                     internal hard drive Mac and PC 4TB (ST4000DM004).    132.99        98.99         1  12655397.0        5397  Data Storage Solutions                    []
# 444      APP0530                                                                  Apple AirPort Time Capsule 2TB                                                                                                       Base Airport 802.11ac Wi-Fi and 2TB hard drive.    329.00       321.80         0  11935397.0        5397  Data Storage Solutions                    []
# 445      APP0531                                                                  Apple AirPort Time Capsule 3TB                                                                                                       Base Airport 802.11ac Wi-Fi and 3TB hard drive.    429.00       416.80         0  11935397.0        5397  Data Storage Solutions                    []
# 453      SEA0054                                         Seagate 2TB HDD NAS 35 "5900RPM SATA III Hard Drive NAS                                                                                                         internal hard drive to 2TB NAS (ST2000VN000).    110.00        89.99         0  12655397.0        5397  Data Storage Solutions                    []
# 454      SEA0055                                         Seagate 3TB HDD NAS 35 "5900RPM SATA III Hard Drive NAS                                                                                                        internal hard drive for 3TB NAS (ST3000VN000).    149.00       119.99         0  12655397.0        5397  Data Storage Solutions                    []
# 455      SEA0056                                             NAS Seagate 4TB HDD Hard Drive 35 "SATA III 5900Rpm                                                                                                          internal hard drive to 4TB NAS (ST4000VN000)    194.00       136.58         0  12655397.0        5397  Data Storage Solutions                    []
# 477      OWC0082                                                 Envoy OWC USB 3.0 SSD Case for Macbook Air 2012                                                                                              Box Portable External USB 2.0 / 3.0 for MacBook Air SSD.     60.99        39.99         0  11935397.0        5397  Data Storage Solutions                    []
# 478      WDT0321                                                                   WD Blue 500GB 25 "5400rpm 7mm                                                                               Western Digital Internal Hard Drive 500GB SATA 5400 rpm for Mac and PC.     60.00        45.00         1  12655397.0        5397  Data Storage Solutions                    []
# 479      WDT0178                                                                     Blue 1TB WD 25 "5400rpm 7mm                                                                                     Western Digital Internal Hard Disk 1TB for Mac and PC (WD10SPCX).    104.00       102.90         0  12655397.0        5397  Data Storage Solutions                    []
# 481      WDT0181                                     Western Digital 2TB Green 35 "5400rpm hard drive Mac and PC                                                                                                                WD Internal Hard Drive 2TB Mac and PC.     90.00        82.58         0  12655397.0        5397  Data Storage Solutions                    []
# 483      WDT0184                                           Western Digital 1TB Red 25 "Mac PC and NAS hard drive                                                                                                   WD Hard Drive 1TB NAS designed for 95mm (WD10JFCX).     85.00        79.99         0  12655397.0        5397  Data Storage Solutions                    []
# 484      WDT0185                                                      Red 750GB WD 25 "Mac PC hard drive and NAS                                                                                  Western Digital hard drive designed for NAS 750GB 95mm (WD7500BFCX).    639.90        70.58         0  12655397.0        5397  Data Storage Solutions                    []
# 485      SEA0057                                         Seagate 500GB SSHD Hybrid disc 25 "Mac and PC hard disk                                                                                         Hybrid Hard Drive Mac and PC and 7mm 500GB SSHD (ST500LM000).     79.99        76.58         0  12655397.0        5397  Data Storage Solutions                    []
# 486      NTE0053                                                    NewerTech miniStack Classic Mac external box                                                                                                             Mac external box 35 FireWire 800 USB 2.0.     64.99        44.99         0  12995397.0        5397  Data Storage Solutions                    []
# 509      SAN0044                                                          SanDisk Ultra 16GB USB 3.0 Flash Drive                                                                                                  USB 3.0 flash drive 16GB USB Flash Drive Mac and PC.      8.26         1.00         1  11935397.0        5397  Data Storage Solutions                    []
# 510      SAN0045                                                          SanDisk Ultra 32GB USB 3.0 Flash Drive                                                                                                  USB 3.0 flash drive 32GB USB Flash Drive Mac and PC.     16.00        13.99         1  11935397.0        5397  Data Storage Solutions                    []
# 511      SAN0046                                                             SanDisk Ultra 64GB USB 3.0 PenDrive                                                                                                  USB 3.0 flash drive 64GB USB Flash Drive Mac and PC.     31.00        25.00         1  11935397.0        5397  Data Storage Solutions                    []
# 575      SAN0047                              SanDisk Ultra microSDHC Memory Card UHS Class 1 | 8GB + SD Adapter                                                                                      MicroSDHC UHS Class 1 Card 8GB with SD adapter speed of 30MB / s      5.00         3.49         0  57445397.0        5397  Data Storage Solutions                    []
# 581      KIN0086                                                  Kingston DataTraveler G4 PenDrive 64GB USB 3.0                                                                                                                           64GB USB pendrive with cap.     23.00        22.28         0  11935397.0        5397  Data Storage Solutions                    []
# 582      OWC0088                                OWC Mercury Elite Pro QX2 aluminum box eSata / FW800 / USB3 RAID                                                                                   Mac and PC RAID 4 bay with connection eSata / FW800 / FW400 / USB3.    362.99       274.90         0  11935397.0        5397  Data Storage Solutions                    []
# 583      KIN0087                                                 Kingston DataTraveler G4 PenDrive 128GB USB 3.0                                                                                                                          128GB USB pendrive with cap.     44.99        42.28         0  57445397.0        5397  Data Storage Solutions                    []
# 584      KIN0088                                                  Kingston DataTraveler G4 PenDrive 16GB USB 3.0                                                                                                                           16GB USB pendrive with cap.      7.00         7.28         0  57445397.0        5397  Data Storage Solutions                    []
# 585      KIN0089                                                  Kingston 32GB DataTraveler USB 3.0 PenDrive G4                                                                                                                           32GB USB pendrive with cap.     15.00        15.28         0  57445397.0        5397  Data Storage Solutions                    []
# 586      KIN0090                                                   Kingston DataTraveler G4 8GB PenDrive USB 3.0                                                                                                                            8GB USB pendrive with cap.     57.80        57.80         0  57445397.0        5397  Data Storage Solutions                    []
# 587      LAC0099                                                       LaCie Porsche Design P9223 Slim 500GB HDD                                                                                         LaCie external hard drive for Mac and PC P9223 500GB USB 3.0.     64.99        64.79         0  11935397.0        5397  Data Storage Solutions                    []
# 588      LAC0213                              LaCie Porsche Design Desktop Drive 3TB USB 3.0 External Hard Drive                                                                                               External Hard Drive 35-inch 3TB USB 3.0 for Mac and PC.    119.99       115.79         0  11935397.0        5397  Data Storage Solutions                    []
# 598      WDT0189                                                     Western Digital My Book for Mac USB 3.0 3TB                                                                                                               WD External Hard Drive USB 3.0 3TB Mac.    149.99       126.79         0  11935397.0        5397  Data Storage Solutions                    []
# 600      WDT0200                                                   Western Digital My Cloud EX4 Cloud NAS Server                                                                                                                      Cloud NAS server WD EX4 diskless    359.00       279.99         0  11935397.0        5397  Data Storage Solutions                    []
# 605      WDT0187                                                       Blue 1TB WD 25 "SATA III 5400rpm 8MB 95mm                                                                                    Internal Hard Drive Western Digital 1TB for Mac and PC (WD10JPVX).     80.00        60.58         0  12655397.0        5397  Data Storage Solutions                    []
# 615      WDT0205                                                        2TB WD My Cloud Gigabit Ethernet USB 3.0                                                                                                        WD 2TB External Hard Drive with cloud storage.    169.00       135.99         0  11935397.0        5397  Data Storage Solutions                    []
# 616      WDT0204                                                        WD My Cloud 3TB Gigabit Ethernet USB 3.0                                                                                                        WD 3TB External Hard Drive with cloud storage.    169.99       150.79         0  11935397.0        5397  Data Storage Solutions                    []
# 617      WDT0206                                                        WD My Cloud 4TB Gigabit Ethernet USB 3.0                                                                                                        WD external hard drive with 4TB cloud storage.    209.99       170.79         0  12995397.0        5397  Data Storage Solutions                    []
# 618      WDT0192                                       Western Digital My Book Studio 2TB USB 3.0 Hard Drive Mac                                                                                                           WD External Hard Drive USB 3.0 Mac desktop.    155.00       104.99         0  11935397.0        5397  Data Storage Solutions                    []
# 619      WDT0197                                                 Western Digital My Book Thunderbolt Duo 8TB Mac                                                                                                   WD External Hard Drive Mac and PC with Thunderbolt.    599.99       539.90         0  11935397.0        5397  Data Storage Solutions                    []
# 620      WDT0196                                                 Western Digital My Book Thunderbolt Duo 6TB Mac                                                                                                   WD External Hard Drive Mac and PC with Thunderbolt.    529.99       366.99         0  11935397.0        5397  Data Storage Solutions                    []
# 622      QNA0067                                                              QNAP TS-212P NAS server Mac and PC                                                                                                          NAS server 2 bays for domestic use and SMEs.    151.25       124.99         0  12175397.0        5397  Data Storage Solutions                    []
# 631      PAC0339                                                          NewerTech miniStack 4TB Hard Drive Mac                                                                                                                    External Box Hard Drive Mac + 4TB.    219.99       219.99         0  11935397.0        5397  Data Storage Solutions                    []
# 642      PAC0335                                                            OWC Mercury Elite Pro QX2 Quad + 8TB                                                                             RAID system Mac and PC 4 bays eSata / FW800 / FW400 / USB3 + 8TB (4x2TB).    722.95       531.37         0  11935397.0        5397  Data Storage Solutions                    []
# 662      PAC0336                                                           OWC Mercury Elite Pro QX2 Quad + 12TB                                                                                               RAID 4 bay eSata / FW800 / FW400 / USB3 + 12TB (4x3TB).    810.99       614.37         0  11935397.0        5397  Data Storage Solutions                    []
# 663      PAC0337                                                           OWC Mercury Elite Pro QX2 Quad + 16TB                                                                            RAID system Mac and PC 4 bays eSata / FW800 / FW400 / USB3 + 16TB (4x4TB).    894.95       671.37         0  11935397.0        5397  Data Storage Solutions                    []
# 666      SNN0027                                         Sonnet Echo Express III-D Chassis expansion Thunderbolt                                                                                                   Thunderbolt external box card PCIe ExpressCard Mac.   1087.79       978.90         0  12995397.0        5397  Data Storage Solutions                    []
# 667      PRO0015                                       Promise Pegasus2 R4 8TB RAID Hard Drive Mac Thunderbolt 2                                                                                                         RAID Thunderbolt 2 Pegasus2 R4 8TB (4 x 2TB).   1421.75      1180.22         0  11935397.0        5397  Data Storage Solutions                    []
# 668      SEA0060                                                               Seagate 1TB SSHD Hybrid disc 35 "                                                                                                  Hybrid Hard Drive Mac and PC 8GB SSD + 1TB 7200 rpm.     90.00        76.99         0  12655397.0        5397  Data Storage Solutions                    []
# 669      SEA0061                                                               2TB Seagate SSHD Hybrid disc 35 "                                                                                                  Hybrid Hard Drive Mac and PC + 8GB SSD 2TB 7200 rpm.    121.00        97.99         0  12655397.0        5397  Data Storage Solutions                    []
# 670      PRO0016                                      Pegasus2 Promise R6 12TB RAID Hard Drive Mac Thunderbolt 2                                                                                                                  RAID Thunderbolt 2 R6 12TB (6 x 2TB)   2117.50      1746.82         0  11935397.0        5397  Data Storage Solutions                    []
# 671      PRO0017                                      Pegasus2 Promise R6 18TB RAID Hard Drive Mac Thunderbolt 2                                                                                            RAID system 18TB R6 Thunderbolt 2 (6 x 3TB) for Mac and PC   2843.50      2316.82         0  11935397.0        5397  Data Storage Solutions                    []
# 679      SYN0088                                                           Synology Surveillance Station VS240HD                                                                                                    monitoring station to monitor up to 24 IP cameras.    453.99       452.99         0  12175397.0        5397  Data Storage Solutions                    []
# 680      OWC0096                                            OWC Mercury Elite Pro Dual Box USB 3.0 / Thunderbolt                                                                              RAID outer box 35 inch SATA connection Thundebolt / USB3 for Mac and PC.    294.99       289.99         0  11935397.0        5397  Data Storage Solutions                    []
# 687      PAC0374                                                    OWC Mercury Elite Pro Dual Thunderbolt 4TB +                                                                             RAID outer box 35 inch SATA connection Thunderbolt / USB3 for Mac and PC.    474.97       431.99         0  11935397.0        5397  Data Storage Solutions                    []
# 688      PAC0375                                                    OWC Mercury Elite Pro Dual Thunderbolt + 6TB                                                                           RAID outer box 35 inch SATA connection Thunderbolt / USB3 Mac and PC + 6TB.    518.99       477.99         0  11935397.0        5397  Data Storage Solutions                    []
# 689      PAC0376                                                    OWC Mercury Elite Pro Dual Thunderbolt + 8TB                                                                           RAID outer box 35 inch SATA connection Thunderbolt / USB3 Mac and PC + 8TB.   5609.70      5549.90         0  11935397.0        5397  Data Storage Solutions                    []
# 694      PAC0383                                                         QNAP TS-212P Pack | Seagate 4TB Desktop                                                                                                   Pack NAS Server QNAP TS-212P + 4TB Seagate Desktop.    331.23       265.99         0  12175397.0        5397  Data Storage Solutions                    []
# 695      PAC0384                                                         QNAP TS-212P Pack | 6TB Seagate Desktop                                                                                    Pack NAS server QNAP TS-212P + 6TB Seagate Desktop for Mac and PC.    375.25       318.99         0  12175397.0        5397  Data Storage Solutions                    []
# 696      PAC0385                                                         QNAP TS-212P Pack | 8TB Seagate Desktop                                                                                               QNAP TS-212P Pack + 8TB Seagate Desktop for Mac and PC.    401.05       385.99         0  12175397.0        5397  Data Storage Solutions                    []
# 708      KIN0092                                                                    Kingston V300 SSD Disk 480GB                                                                                                             SSD 480GB SATA Hard Drive Mac and PC III.    172.99       164.58         0  12215397.0        5397  Data Storage Solutions                    []
# 730      PRO0020                                      R8 Pegasus2 Promise RAID 24TB Hard Disk Thunderbolt 2 Macc                                                                                                                 RAID Thunderbolt 2 R8 24TB (8 x 3TB).   3499.00      2812.43         0  11935397.0        5397  Data Storage Solutions                    []
# ...
# 10277    PAC2500                             OWC ThunderBay RAID Thunderbolt 4 3 | 8TB (4x2TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   1044.95       898.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10278    PAC2501                             OWC ThuderBay RAID Thunderbolt 4 3 | 12TB (4x3TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   1164.95       974.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10279    PAC2502                             OWC ThuderBay RAID Thunderbolt 4 3 | 16TB (4x4TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   1324.95      1042.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10280    PAC2503                             OWC ThuderBay RAID Thunderbolt 4 3 | 24TB (4x6TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   1724.95      1341.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10281    PAC2504                             OWC ThuderBay RAID Thunderbolt 4 3 | 32TB (4x8TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   2044.95      1474.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10282    PAC2505                            OWC ThuderBay RAID Thunderbolt 4 3 | 40TB (4x10TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   2204.95      1690.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10283    PAC2506                            OWC ThuderBay RAID Thunderbolt 4 3 | 48TB (4x12TB) Seagate Iron Wolf                                                                               RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3   2604.95      2081.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10285    OWC0278                                                      ThunderBay OWC Dual Thunderbolt RAID 5 4 3                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3    725.99       689.99         1  11935397.0        5397  Data Storage Solutions                    []
# 10286    PAC2493                            OWC ThuderBay Thunderbolt RAID 5 4 3 | 8TB (4x2TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   1165.95       998.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10287    PAC2494                           OWC ThuderBay Thunderbolt RAID 5 4 3 | 12TB (4x3TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   1285.95      1074.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10288    PAC2495                           OWC ThuderBay Thunderbolt RAID 5 4 3 | 16TB (4x4TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   1445.95      1141.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10289    PAC2496                           OWC ThuderBay Thunderbolt RAID 5 4 3 | 24TB (4x6TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   1845.95      1442.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10290    PAC2497                           OWC ThuderBay Thunderbolt RAID 5 4 3 | 32TB (4x8TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   2165.95      1574.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10291    PAC2498                          OWC ThuderBay Thunderbolt RAID 5 4 3 | 40TB (4x10TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   2325.95      1790.37         1  11935397.0        5397  Data Storage Solutions                    []
# 10292    PAC2499                          OWC ThuderBay Thunderbolt RAID 5 4 3 | 48TB (4x12TB) Seagate Iron Wolf                                                                            outer box with RAID5 disc 25 inch and 35 inch two connectors Thunderbolt 3   2725.95      2182.37         0  11935397.0        5397  Data Storage Solutions                    []
# 10313    TRA0051                                                           Transcend JetDrive PCIe SSD 825 240GB                                                                 240GB SSD expansion for Macbook Pro Retina MacBook Air Mac Pro and Mac mini Kit tools    269.99       269.00         1  12215397.0        5397  Data Storage Solutions                    []
# 10314    TRA0052                                                           Transcend JetDrive PCIe SSD 825 480GB                                                                 480GB SSD expansion for Macbook Pro Retina MacBook Air Mac Pro and Mac mini Kit tools    439.99       438.99         0  12215397.0        5397  Data Storage Solutions                    []
# 10351    SEA0093                                    Seagate Backup Plus Portable USB 3.0 External Disk 4TB Black                                                                      lightweight portable external hard drive and 25-inch 4TB USB 3.0 for Mac and PC.    149.99       125.99         1  11935397.0        5397  Data Storage Solutions                    []
# 10352    SEA0120                                    Seagate Backup Plus Portable USB 3.0 external disk 5TB Black                                                                      lightweight portable external hard drive and 25-inch 5TB USB 3.0 for Mac and PC.    169.99       159.99         1  11935397.0        5397  Data Storage Solutions                    []
# 10353    SEA0117                                    Seagate Backup Plus Portable USB 3.0 External Disk 4TB Plata                                                                      lightweight portable external hard drive and 25-inch 4TB USB 3.0 for Mac and PC.    149.99       127.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10354    SEA0121                                    Seagate Backup Plus Portable USB 3.0 external disk 5TB Plata                                                                      lightweight portable external hard drive and 25-inch 5TB USB 3.0 for Mac and PC.    179.99       159.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10355    SEA0118                                     Seagate Backup Plus Portable USB 3.0 External Disk 4TB Blue                                                                      lightweight portable external hard drive and 25-inch 4TB USB 3.0 for Mac and PC.    149.99       127.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10356    SEA0122                                     Seagate Backup Plus Portable USB 3.0 external disk 5TB Blue                                                                      lightweight portable external hard drive and 25-inch 5TB USB 3.0 for Mac and PC.    179.99       159.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10357    SEA0119                                      Seagate Backup Plus Portable USB 3.0 External Disk 4TB Red                                                                      lightweight portable external hard drive and 25-inch 4TB USB 3.0 for Mac and PC.    149.99       127.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10358    SEA0123                                      Seagate Backup Plus Portable USB 3.0 external disk 5TB Red                                                                      lightweight portable external hard drive and 25-inch 5TB USB 3.0 for Mac and PC.    179.99       159.99         0  11935397.0        5397  Data Storage Solutions                    []
# 10362    SEA0124                                                  Seagate Backup Plus Hub USB 3.0 Hard Drive 4TB                                                                                        Seagate desktop hard drive with 4TB compatible with Mac and PC    149.99       125.00         0  11935397.0        5397  Data Storage Solutions                    []
# 10363    SEA0125                                                  Seagate Backup Plus Hub USB 3.0 Hard Drive 6TB                                                                                        Seagate desktop hard drive with 6TB compatible with Mac and PC    184.99       159.00         1  11935397.0        5397  Data Storage Solutions                    []
# 10364    SEA0126                                                  Seagate Backup Plus Hub USB 3.0 Hard Drive 8TB                                                                                        Seagate desktop hard drive with 8TB compatible with Mac and PC    239.99       213.99         1  11935397.0        5397  Data Storage Solutions                    []
# 10371    OWC0280                                               OWC Envoy Pro EX 250GB SSD M.2 PCIe Thunderbolt 3                                                                                                      outer box with SSD M.2 inch 250GB for Mac and PC    338.99       327.80         0  11935397.0        5397  Data Storage Solutions                    []
# 10372    OWC0281                                                 OWC Envoy Pro EX M.2 PCIe SSD 1TB Thunderbolt 3                                                                                                        outer box with SSD M.2 inch 1TB for Mac and PC    725.99       697.79         0  11935397.0        5397  Data Storage Solutions                    []
# 10394    WDT0412                                                                 WD 120GB SSD NAND 3D Green SATA                                                                                                             120GB SSD SATA 3 (6Gb / s) for Mac and PC     65.00        48.99         1  12655397.0        5397  Data Storage Solutions                    []
# 10395    WDT0413                                                                 WD 240GB SSD NAND 3D Green SATA                                                                                                             240GB SSD SATA 3 (6Gb / s) for Mac and PC     85.00        76.99         1  12655397.0        5397  Data Storage Solutions                    []
# 10407  WDT0333-A                                      Open - Western Digital My Passport Ultra 4TB USB 3.0 Black                                                                   External hard disk capacity 4TB reconditioned and USB 3.0 connection for Mac and PC    189.99       147.49         0  11935397.0        5397  Data Storage Solutions                    []
# 10416  TRA0025-A                Open - Transcend StoreJet SSD 500 512GB External Hard Disk Thunderbolt / USB 3.0                                                                   External Hard Drive 512GB SSD refitted with Thunderbolt and USB 3.0 for Mac and PC.    520.00       339.78         0  11935397.0        5397  Data Storage Solutions                    []
# 10417  OWC0258-A                                            Open - OWC Aura Pro SSD 480GB + X + Aura Envoy Tools                                                                  Kit 480GB SSD expansion Refurbished Mac Pro 2013 Finals tools and housing Aura Envoy    580.99       363.34         0  12215397.0        5397  Data Storage Solutions                    []
# 10420  SYN0172-A                                           Open - Synology DS918 + NAS Server 4GB Ram Mac and PC                                       Reconditioned Plus Series of NAS Enterprise Server seeking high performance and the ability to scale memory and    574.99       557.07         0  12175397.0        5397  Data Storage Solutions                    []
# 10483  OWC0262-A                                               Open - OWC Express External box 25 "USB 3.0 Plata                                                                                         Outer carton for HDDs and SDD format 25 inches for Mac and PC     36.99        13.00         0  11935397.0        5397  Data Storage Solutions                    []
# 10507  CRU0054-A                                                              Open - Crucial MX500 250GB SSD 7mm                                                                                       Hard disk SATA 250GB SSD refitted III (6 Gb / s) for Mac and PC     86.53        66.99         0  12215397.0        5397  Data Storage Solutions                    []
# 10509  SAN0106-A                                             Open - SanDisk Ultra Flair Flash Drive 64GB USB 3.0                                                                                       Reconditioned pendrive USB 3.0 64GB USB Flash Drive Mac and PC.     24.99        20.79         0  57445397.0        5397  Data Storage Solutions                    []
# 10518    WDT0417                                                              WD Hard Drive 6TB Gold 35 "Servers                                                           Hard Western Digital 6TB 35 inches SATA 6 Gb / s for servers and enterprise storage systems    329.00       256.58         0  12655397.0        5397  Data Storage Solutions                    []
# 10519    WDT0416                                                              WD Hard Drive 8TB Gold 35 "Servers                                                           Hard Western Digital 8TB 35 inches SATA 6 Gb / s for servers and enterprise storage systems    419.00       305.99         1  12655397.0        5397  Data Storage Solutions                    []
# 10520    WDT0415                                                             WD Hard Drive 10TB Gold 35 "Servers                                                          Hard Western Digital 10TB 35 inches SATA 6 Gb / s for servers and enterprise storage systems    519.00       386.58         0  12655397.0        5397  Data Storage Solutions                    []
# 10521    WDT0414                                                             WD Hard Drive 12TB Gold 35 "Servers                                                          Hard Western Digital 12TB 35 inches SATA 6 Gb / s for servers and enterprise storage systems    689.00       426.58         0  12655397.0        5397  Data Storage Solutions                    []

# %%
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords


# Ensure you have the stopwords downloaded
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# we need a Function to clean text and tokenize it, while doing a stopword removal
def clean_and_tokenize(text):
    # we are setting everything to Lowercase, removing the non-alphanumeric characters, and split the strings into words
    if not isinstance(text, str):
        text = str(text) if pd.notnull(text) else ''
    # we are tokenizing with a regular expression and then removing the stopwords like "and", "or" and so on
    words = re.findall(r'\b\w+\b', text.lower())
    return [word for word in words if word not in stop_words]

# we now need a Function to extract the last 4 digits from the 'type' column since the last 4 digits refer to the type of the item while the numbers that come before the last 4 digits of the type column refer to the subcategory.
def extract_last_4_digits(type_value):

    try:
        if pd.notnull(type_value):
            type_str = str(int(float(type_value)))  # We just want a filter for numeric like strings here since we already tokenized the words
            return type_str[-4:]  # now we are extracting the last 4 characters from the type column
    except (ValueError, TypeError):  # sometimes the value is NaN, which we need to catch or else it won't work since there is a dtype mismatch
        pass
    return 'unknown'  # all the NaN values will get an "unknown" assigned to them for easier filtering out later

# Now that we have the 4 last digits, this is enough for assigning a category to the items but I want to go a step further and see which words are most common for the different categories, to see if there are any unexpected words in there (for example, I dont want to see "iMac" in the "iPhone" type which is 1716)
def get_common_words_by_last_4_digits(df, top_n=5):
    # we are defining an empty Dictionary to hold common words for each type (based on last 4 digits)
    common_words_by_type = {}

    # we are creating a new column for the last 4 digits of 'type'


    #  and then group by the last 4 digits of type
    grouped_by_last_4 = df.groupby('type_last_4')

    for last_4_digits, group in grouped_by_last_4:
        # for easier filtering, we are combining the name and desc column since they are almost identical in their keywords anyways
        combined_texts = group['name'].fillna('') + ' ' + group['desc'].fillna('')

        # and now we are just tokenizing and cleaning the combined text again (we have done this before but only for the respective columns. This is basically just to ensure that the combined columns are still readable)
        all_words = []
        for text in combined_texts:
            words = clean_and_tokenize(text)  # just cleaning and removing stopwords again
            all_words.extend(words)

        # we define a filter with the "Counter" module that conveniently counts all the words for us and lists them by frequency
        word_counts = Counter(all_words)

        # And now just another definition to get the most common words, we then store for later use (at the end of the code)
        common_words = word_counts.most_common(top_n)  # Top N most common words
        common_words_by_type[last_4_digits] = [word for word, _ in common_words]

    return common_words_by_type

# This is a predefined map, we use for assigning a category to the different types we extracted before (up there, in the def_extract_type_last_4 function )
CATEGORY_MAPPING = {
    '0142': 'Internal & External Batteries',
    '0230': 'Backpacks & Briefcases',
    '1216': 'Supports & Stands',
    '1229': 'Pens & Stylus',
    '1230': 'Cables & Adapters',
    '1231': 'Applecare',
    '1276': 'PCIe Adapters',
    '1280': 'NAS Systems & Accessories',
    '1282': 'MacBooks & iMACs',
    '1296': 'Monitors & Displays',
    '1298': 'Refurbished & Used Products',
    '1325': 'Cables & Adapters',
    '1334': 'Network',
    '1364': 'RAM Modules',
    '1375': 'Microphones',
    '1387': 'Mouse & Trackpads',
    '1392': 'Backpacks & Briefcases',
    '1404': 'NAS Systems & Accessories',
    '1405': 'Graphical Tablets & Accessories',
    '1416': 'Software',
    '1424': 'Optical Drives & Recorders',
    '1433': 'Data Storage Solutions',
    '1434': 'Cables & Adapters',
    '1515': 'Internal & External Batteries',
    '1714': 'iPads',
    '1715': 'iPods',
    '1716': 'iPhones',
    '1859': 'Smart Home',
    '2062': 'Device Services & Warranties',
    '2158': 'MacBooks & iMACs',
    '2282': 'Supports & Stands',
    '2425': 'Apple Smartwatch Accessories',
    '2434': 'Apple Smartwatch Accessories',
    '2449': 'Apple Smartwatch Accessories',
    '4259': 'Apple TV & Streaming Devices/Accessories',
    '5185': 'Apple Smartwatch',
    '5384': 'Headphones',
    '5395': 'Cables & Adapters',
    '5397': 'Data Storage Solutions',
    '5398': 'Speakers',
    '5399': 'Chargers & Charging Docks',
    '5400': 'Device Accessories',
    '5401': 'Keyboards & Keypads',
    '5403': 'Protectors & Covers',
    '5404': 'Device Accessories',
    '5405': 'Device Accessories',
    '5406': 'Repair Parts & Tools',
    '5407': 'Repair Parts & Tools',
    '5720': 'Supports & Stands',
    '8696': 'Supports & Stands',
    '9094': 'Home Security Cameras & Devices',
    'unknown': 'Uncategorized'
}

# just a quick and dirty function to assign category based on the predefined mapping
def assign_category_by_mapping(last_4_digits):
    return CATEGORY_MAPPING.get(last_4_digits, 'Uncategorized')


products_df['type_last_4'] = products_df['type'].apply(extract_last_4_digits) # We want a column that shows only the last 4 digits of every type value so we can map to it easier later and also to ignore subcategories
products_df['category'] = products_df['type_last_4'].apply(assign_category_by_mapping)  # We are creating a category column here and filling it with the predefined map, going by their type_last_4 value we extracted earlier

# This is just to understand the dataframe structure a bit better and is not necessary but we are looking at the 10 most common words for each type to see if there are any similarities
common_words_by_type = get_common_words_by_last_4_digits(products_df, top_n=10)
print("Most common words for each last 4 digits of 'type':")
for last_4_digits, words in common_words_by_type.items():
    print(f"Last 4 digits: {last_4_digits}")
    print(f"  Most common words: {words}")
    print("\n")

# I just wanted to display the updated dataframe with categories now applied
print("Updated DataFrame with Categories:")
print(products_df.head(20))  # we are just displaying the first few rows to see if the functions work corecctly. We still have to check manually
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Most common words for each last 4 digits of 'type':
# Last 4 digits: 0142
#   Most common words: ['battery', 'macbook', 'pro', '13', 'inch', 'newertech', 'nupower', '15', 'late', '2009']
#
#
# Last 4 digits: 0230
#   Most common words: ['macbook', 'pro', 'retina', '15', '13', 'black', 'case', 'tucano', 'bag', 'inch']
#
#
# Last 4 digits: 1216
#   Most common words: ['ipad', 'support', 'iphone', 'security', 'pro', 'stand', 'black', 'mini', '6', 'adjustable']
#
#
# Last 4 digits: 1229
#   Most common words: ['pointer', 'ipad', 'pen', 'iphone', 'stylus', 'digital', 'wacom', 'jot', 'adonit', 'bamboo']
#
#
# Last 4 digits: 1230
#   Most common words: ['cable', 'lightning', 'usb', 'ipod', 'iphone', 'ipad', 'apple', 'white', 'charge', 'sync']
#
#
# Last 4 digits: 1231
#   Most common words: ['apple', 'applecare', 'extended', 'warranty', 'protection', 'care', 'plan', 'macbook', 'pro', 'mac']
#
#
# Last 4 digits: 1276
#   Most common words: ['card', 'pcie', 'mac', '3', 'sonnet', '2', '0', 'usb', 'pc', 'adapter']
#
#
# Last 4 digits: 1280
#   Most common words: ['mac', 'expansion', 'nas', 'synology', 'pc', 'server', 'mini', 'unit', 'module', '12']
#
#
# Last 4 digits: 1282
#   Most common words: ['ram', 'core', 'apple', 'flash', 'i5', '8gb', 'imac', 'retina', 'macbook', 'pro']
#
#
# Last 4 digits: 1296
#   Most common words: ['monitor', 'inch', 'mac', 'hdmi', 'pc', '27', 'ips', '4k', 'dell', 'lg']
#
#
# Last 4 digits: 1298
#   Most common words: ['open', 'iphone', 'mac', 'usb', 'macbook', 'pro', 'pc', 'case', '3', 'ipad']
#
#
# Last 4 digits: 1325
#   Most common words: ['cable', 'usb', 'c', 'thunderbolt', '3', 'adapter', 'hdmi', 'mini', 'mac', 'belkin']
#
#
# Last 4 digits: 1334
#   Most common words: ['link', 'router', 'wi', 'fi', 'gigabit', 'wireless', 'switch', 'ports', 'kit', 'wifi']
#
#
# Last 4 digits: 1364
#   Most common words: ['mac', 'memory', 'dimm', 'ram', 'pro', 'ddr3', 'imac', 'owc', '8gb', '16gb']
#
#
# Last 4 digits: 1375
#   Most common words: ['microphone', 'usb', 'blue', 'microphones', 'mac', 'snowball', 'professional', 'connection', 'yeti', 'capsules']
#
#
# Last 4 digits: 1387
#   Most common words: ['mouse', 'wireless', 'apple', 'mac', 'trackpad', 'logitech', 'aluminum', 'magic', '2', 'bluetooth']
#
#
# Last 4 digits: 1392
#   Most common words: ['macbook', 'backpack', '15', '13', 'pro', 'inch', 'black', 'retina', 'inches', 'air']
#
#
# Last 4 digits: 1404
#   Most common words: ['nas', 'synology', 'expansion', 'qnap', 'card', 'rail', 'kit', 'bays', 'ram', 'memory']
#
#
# Last 4 digits: 1405
#   Most common words: ['tablet', 'wacom', 'graphics', 'pen', 'mac', 'pc', 'intuos', 'pro', 'touch', '2']
#
#
# Last 4 digits: 1416
#   Most common words: ['mac', 'adobe', 'cc', 'software', 'pc', 'license', 'home', 'office', 'update', 'edition']
#
#
# Last 4 digits: 1424
#   Most common words: ['recorder', 'dvd', 'external', 'slim', 'mac', 'ultra', 'usb', 'macbook', 'pro', 'samsung']
#
#
# Last 4 digits: 1433
#   Most common words: ['kit', 'ssd', 'expansion', 'pro', 'macbook', 'ram', '2012', 'mac', 'imac', 'datadoubler']
#
#
# Last 4 digits: 1434
#   Most common words: ['adapter', 'mac', 'pro', 'apple', 'security', 'lock', 'cable', 'padlock', 'end', '2013']
#
#
# Last 4 digits: 1515
#   Most common words: ['battery', 'external', 'usb', 'iphone', 'ipad', 'mah', 'power', 'mophie', 'ipod', 'lightning']
#
#
# Last 4 digits: 1714
#   Most common words: ['ipad', 'wi', 'fi', 'apple', 'pro', 'cellular', 'new', '9', '32gb', '128gb']
#
#
# Last 4 digits: 1715
#   Most common words: ['ipod', 'touch', 'apple', 'generation', '16gb', 'new', 'nano', 'music', 'player', '6th']
#
#
# Last 4 digits: 1716
#   Most common words: ['iphone', 'apple', 'new', 'free', 'plus', '7', 'gold', 'like', '32gb', '6s']
#
#
# Last 4 digits: 1859
#   Most common words: ['sensor', 'homekit', 'fibaro', 'multi', 'door', 'window', 'function', 'doors', 'windows', 'compliant']
#
#
# Last 4 digits: 2062
#   Most common words: ['installation', 'ram', 'ssd', 'service', 'pro', 'hdd', 'macbook', 'data', 'transfer', 'mac']
#
#
# Last 4 digits: 2158
#   Most common words: ['pro', 'core', 'ssd', 'ram', 'pcie', 'apple', 'macbook', 'inch', '16gb', 'touch']
#
#
# Last 4 digits: 2282
#   Most common words: ['apple', 'watch', 'belkin', 'travel', 'support', 'black', 'compact', 'portable', 'stand', 'vertically']
#
#
# Last 4 digits: 2425
#   Most common words: ['protector', 'apple', 'watch', 'screen', 'tempered', 'glass', '42mm', 'zagg', 'invisibleshield', '38mm']
#
#
# Last 4 digits: 2434
#   Most common words: ['apple', 'watch', 'case', 'housing', 'anti', 'shock', '42mm', '38mm', 'griffin', 'survivor']
#
#
# Last 4 digits: 2449
#   Most common words: ['apple', 'strap', 'watch', '42mm', '38mm', 'sports', 'mm', 'black', 'leather', 'durable']
#
#
# Last 4 digits: 4259
#   Most common words: ['apple', 'player', 'tv', 'remote', 'media', 'multimedia', 'siri', 'case', 'new', '32gb']
#
#
# Last 4 digits: 5185
#   Most common words: ['apple', 'watch', 'strap', 'case', 'sport', 'series', 'aluminum', 'gps', '38mm', '42mm']
#
#
# Last 4 digits: 5384
#   Most common words: ['headphones', 'iphone', 'ipad', 'ipod', 'headset', 'wireless', 'bluetooth', 'black', 'beats', 'ear']
#
#
# Last 4 digits: 5395
#   Most common words: ['usb', 'adapter', 'c', '3', 'mac', '0', 'hdmi', 'hub', 'macbook', 'sd']
#
#
# Last 4 digits: 5397
#   Most common words: ['mac', 'pc', 'nas', 'hard', 'drive', 'ram', '3', 'usb', 'server', 'wd']
#
#
# Last 4 digits: 5398
#   Most common words: ['speaker', 'bluetooth', 'iphone', 'ipad', 'ipod', 'portable', 'wireless', 'black', 'waterproof', 'jbl']
#
#
# Last 4 digits: 5399
#   Most common words: ['charger', 'apple', 'iphone', 'charging', 'watch', 'usb', 'car', 'dock', 'lightning', 'macbook']
#
#
# Last 4 digits: 5400
#   Most common words: ['ipad', 'iphone', 'gopro', 'ipod', 'support', 'usb', 'calibrator', 'magic', 'adapter', 'macbook']
#
#
# Last 4 digits: 5401
#   Most common words: ['keyboard', 'mac', 'bluetooth', 'keypad', 'spanish', 'apple', 'wireless', 'ipad', 'iphone', 'aluminum']
#
#
# Last 4 digits: 5403
#   Most common words: ['case', 'iphone', 'plus', '6', '7', '6s', 'ipad', 'cover', 'pro', 'black']
#
#
# Last 4 digits: 5404
#   Most common words: ['iphone', 'ipad', 'ipod', 'bluetooth', 'control', 'white', 'app', 'touch', 'black', 'activity']
#
#
# Last 4 digits: 5405
#   Most common words: ['iphone', 'armband', 'plus', '6', '6s', 'sport', '7', 'bracelet', 'black', '8']
#
#
# Last 4 digits: 5406
#   Most common words: ['kit', 'ifixit', 'iphone', 'tools', 'battery', 'screwdriver', 'imac', 'mac', 'macbook', 'tool']
#
#
# Last 4 digits: 5407
#   Most common words: ['iphone', 'ifixit', 'piece', '5', 'replacement', '5s', '6', 'battery', 'front', 'ipad']
#
#
# Last 4 digits: 5720
#   Most common words: ['iphone', 'support', 'stand', 'car', 'holder', 'aluminum', 'lightning', 'black', '6', 'elago']
#
#
# Last 4 digits: 8696
#   Most common words: ['macbook', 'support', 'aluminum', 'pro', 'imac', 'mac', 'stand', 'design', 'air', 'magic']
#
#
# Last 4 digits: 9094
#   Most common words: ['camera', 'arlo', 'surveillance', 'netgear', 'hd', 'iphone', 'ipad', '2', 'pro', 'night']
#
#
# Last 4 digits: unknown
#   Most common words: ['core', 'ram', 'ssd', 'apple', 'imac', 'retina', 'inch', '27', '5k', 'macbook']
#
#
# Updated DataFrame with Categories:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price  promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99        49.99
# 1           USB ultrathin keyboard Apple Mac Spanish.  59.00        59.00
# 2                              mouse Apple USB cable.  59.00        56.99
# 3               IPhone dock and USB Cable Apple iPod.  25.00        23.00
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# 5   IPhone and iPod AV Cable Dock to Composite Video.  45.00        42.00
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99        14.65
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99        27.47
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...  74.00        66.99
# 9   Adapter Mini Display Port to VGA MacBook and M...  35.00        33.00
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...  35.00        33.00
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99        44.99
# 12                       USB to Ethernet adapter Mac.  35.00        33.00
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).  89.00        84.99
# 14           FireWire 400 adapter cable FireWire 800.  20.00        17.99
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95        24.99
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...  89.00        84.99
# 17  Dock and support with multiple connections for...  69.99        69.99
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99         7.99
# 19                         Dock Connector to VGA IOS.  35.00        35.00
#
#     in_stock        type type_last_4                   category
# 0          1      8696.0        8696          Supports & Stands
# 1          0  13855401.0        5401        Keyboards & Keypads
# 2          0      1387.0        1387          Mouse & Trackpads
# 3          0      1230.0        1230          Cables & Adapters
# 4          1      1364.0        1364                RAM Modules
# 5          0      1230.0        1230          Cables & Adapters
# 6          0      1364.0        1364                RAM Modules
# 7          0      1364.0        1364                RAM Modules
# 8          0      1364.0        1364                RAM Modules
# 9          0      1325.0        1325          Cables & Adapters
# 10         0      1325.0        1325          Cables & Adapters
# 11         0      5384.0        5384                 Headphones
# 12         0      1334.0        1334                    Network
# 13         0  13005399.0        5399  Chargers & Charging Docks
# 14         0      1325.0        1325          Cables & Adapters
# 15         0  13835403.0        5403        Protectors & Covers
# 16         1  13005399.0        5399  Chargers & Charging Docks
# 17         0  12995397.0        5397     Data Storage Solutions
# 18         0  11865403.0        5403        Protectors & Covers
# 19         0  13955395.0        5395          Cables & Adapters

# %%
# sadly, there are a couple of rows that didn't get assigned a category because their type is missing but that should be easily fixed by assigning the type and category based on the most common strings

type_mapping = {
    '2062': ['service including parts and labor', 'It is including parts and labor', 'diagnosis', 'includes parts and labor'],
    '1515': ['battery and LED indicator', 'IPhone Battery Case', 'Housing with battery','Battery Case iPhone','Battery Case','housing with built-in iPhone 6 battery','Case Battery','mAh battery','case with battery','battery cover with'],
    '1716': ['New iPhone 6','New Free iPhone 6','New Free iPhone','New 16GB iPhone','New iPhone SE with','New 64GB iPhone 6S Libre','New iPhone 6 16GB','iPhone 6 Plus 128GB Free','New iPhone 5S','New 64GB iPhone 6'],
    '1282': ['IMac desktop computer','Desktop computer iMac','New MacBook Pro','New MacBook Retina Display','New MacBook', 'inch iMac', 'laptop MacBook Air 13 inch','Mac mini','MacBook Pro','MacBook Retina display','Retina Display MacBook','Apple iMac desktop'],
    '1298': ['Refurbished','reconditioned','refitted','used','revised','as new','open box'],
    '1334': ['Thunderbolt external box 3'],
    '5397': ['Pendrive','flash drive','SDHC memory card'],
    '1404': ['Synology DS1815'],
    '1424': ['video recorder hardware'],
    '1714': ['Pro New iPad'],
    '5384': ['stereo headphones'],
    '1859': ['notifications Ring devices']
}
# Function to assign the type_last_4 value based on matching string in 'desc'
def map_type_last_4(row, type_mapping):
    desc = row['desc']

    # Only process the row if 'desc' is a string (or is not NaN) and type_last_4 is missing (NaN) or 'unknown'
    if isinstance(desc, str) and (pd.isna(row['type_last_4']) or row['type_last_4'] == 'unknown'):
        # Loop over the mapping dictionary
        for type_last_4, keywords in type_mapping.items():
            # Check if any keyword is in the 'desc' (case insensitive match)
            if any(keyword.lower() in desc.lower() for keyword in keywords):
                return type_last_4  # Return the mapped value if a match is found
    return row['type_last_4']  # Otherwise, return the original value

# Now we apply the function to update the type_last_4 column based on the 'desc' content
products_df['type_last_4'] = products_df.apply(map_type_last_4, axis=1, args=(type_mapping,))

# Now we assign 'type' based on 'type_last_4' only if 'category' is 'Uncategorized' AND if 'type' is missing (NaN)
# Also we ensure we do not overwrite existing values of 'type' that are not 'Uncategorized' or 'NaN'
products_df.loc[(products_df['category'] == 'Uncategorized') & (products_df['type'].isna())]

products_df.loc[products_df['sku'].str.startswith('IFX'), 'type_last_4'] = '5406'

products_df['category'] = products_df['type_last_4'].apply(assign_category_by_mapping)


# this section is just for fine tuning outliers, you can do that or not, it is up to you

products_df.loc[products_df['type_last_4'] == '1716', 'price'] = products_df['price'].apply(
    lambda x: round(x * 10, 2) if x < 100 else (round(x / 10, 2) if x > 3000 else x)
)

products_df.loc[products_df['type_last_4'] == '1716', 'promo_price'] = products_df['promo_price'].apply(
    lambda x: round(x * 10, 2) if x < 100 else (round(x / 10, 2) if x > 3000 else x)
)

products_df.loc[products_df['type_last_4'] == '1282', 'price'] = products_df['price'].apply(
    lambda x: round(x / 10, 2) if x > 10000 else x
)

products_df.loc[products_df['type_last_4'] == '1282', 'promo_price'] = products_df['promo_price'].apply(
    lambda x: round(x / 10, 2) if x > 10000 else x
)
products_df.loc[products_df['type_last_4'] == '5403', 'price'] = products_df['price'].apply(
    lambda x: round(x / 10, 2) if x > 200 else x
)

products_df.loc[products_df['type_last_4'] == '5403', 'promo_price'] = products_df['promo_price'].apply(
    lambda x: round(x / 10, 2) if x > 200 else x
)
products_df.loc[products_df['type_last_4'] == '1404', 'price'] = products_df['price'].apply(
    lambda x: round(x / 10, 2) if x > 25000 else x
)

products_df.loc[products_df['type_last_4'] == '1404', 'promo_price'] = products_df['promo_price'].apply(
    lambda x: round(x / 10, 2) if x > 25000 else x
)
products_df.loc[
    (products_df['type_last_4'] == '5397') &
    (products_df['price'] > 6000) &
    (~products_df['desc'].str.contains("Thunderbolt", case=False, na=False)),
    'price'
] = products_df['price'].apply(lambda x: round(x / 10, 2))

products_df.loc[
    (products_df['type_last_4'] == '5397') &
    (products_df['promo_price'] > 6000) &
    (~products_df['desc'].str.contains("Thunderbolt", case=False, na=False)),
    'promo_price'
] = products_df['promo_price'].apply(lambda x: round(x / 10, 2))

# %%
avg_prices = products_df.groupby('type_last_4')[['price', 'promo_price']].mean()

# Define a threshold to identify "heavy deviations" (you can adjust this value as needed)
threshold_percentage = 6.5  # This would represent a 50% deviation (you can adjust it)

# Now let's create a function to detect deviations
def detect_deviations(row, avg_prices, threshold_percentage):
    type_id = row['type_last_4']

    # Fetch the average prices for this type_id
    avg_price = avg_prices.loc[type_id, 'price']
    avg_promo_price = avg_prices.loc[type_id, 'promo_price']

    # Calculate the deviation thresholds
    price_deviation_upper = avg_price * (1 + threshold_percentage)
    price_deviation_lower = avg_price * (1 - threshold_percentage)

    promo_price_deviation_upper = avg_promo_price * (1 + threshold_percentage)
    promo_price_deviation_lower = avg_promo_price * (1 - threshold_percentage)

    # Check if the row's price or promo_price is out of the defined deviation bounds
    deviations = []
    if row['price'] < price_deviation_lower or row['price'] > price_deviation_upper:
        deviations.append('price')
    if row['promo_price'] < promo_price_deviation_lower or row['promo_price'] > promo_price_deviation_upper:
        deviations.append('promo_price')

    # Return a list of deviations, if any
    return deviations

# Apply the function to identify the deviations
products_df['deviations'] = products_df.apply(detect_deviations, args=(avg_prices, threshold_percentage), axis=1)

# Filter rows that have any deviations
deviations_df = products_df[products_df['deviations'].apply(len) > 0]

# Print the rows with deviations (only the rows that have deviations)
print("Rows with price deviations:")
print(deviations_df[['sku', 'type_last_4', 'price', 'promo_price', 'deviations','category']].to_string(index=False))
# Out:
# Rows with price deviations:
#       sku type_last_4    price  promo_price           deviations                                 category
# CRU0015-2        1364  1639.79      1629.89 [price, promo_price]                              RAM Modules
#   KAN0016        5401   599.89       599.89        [promo_price]                      Keyboards & Keypads
#   GRT0312        1216   899.00       898.99 [price, promo_price]                        Supports & Stands
#   REP0188        2062  2099.90      2099.90 [price, promo_price]             Device Services & Warranties
#   MOP0057        1515  1329.91      1329.91 [price, promo_price]            Internal & External Batteries
#   MOP0058        1515  1599.86      1599.86 [price, promo_price]            Internal & External Batteries
#   MOP0059        1515  1599.86      1599.86 [price, promo_price]            Internal & External Batteries
#   PAC0789        1433  7519.59      6435.84 [price, promo_price]                   Data Storage Solutions
#   PAC0716        1433  7629.60      7169.90 [price, promo_price]                   Data Storage Solutions
#   OWC0151        1325   640.99       562.99 [price, promo_price]                        Cables & Adapters
#   OWC0152        1325   701.99       599.99 [price, promo_price]                        Cables & Adapters
#   SMA0007        5404  2699.87      2699.87 [price, promo_price]                       Device Accessories
#   SMA0008        5404  1999.89      1999.89 [price, promo_price]                       Device Accessories
#   SMA0009        5404  1899.94      1899.94 [price, promo_price]                       Device Accessories
#   SNN0049        5395   669.99       669.99 [price, promo_price]                        Cables & Adapters
#   WAC0187        1405 13999.91     13999.91 [price, promo_price]          Graphical Tablets & Accessories
#   APP1498        1714  8328.12      8328.12 [price, promo_price]                                    iPads
# APP0851-A        1298  8590.03      6699.58 [price, promo_price]              Refurbished & Used Products
#   IFX0099        5406   899.90       899.90 [price, promo_price]                     Repair Parts & Tools
#   IFX0080        5406   899.90       899.90 [price, promo_price]                     Repair Parts & Tools
#   IFX0121        5406   649.89       649.89 [price, promo_price]                     Repair Parts & Tools
# DLL0024-A        1298  4589.89      4173.16 [price, promo_price]              Refurbished & Used Products
#   PAC1479        5397   692.97      5921.79        [promo_price]                   Data Storage Solutions
#   PAC2027        5397   653.95      5831.79        [promo_price]                   Data Storage Solutions
#   PAC2033        5397   631.97      5871.79        [promo_price]                   Data Storage Solutions
#   WAC0194        1405 15999.90     15999.90 [price, promo_price]          Graphical Tablets & Accessories
#   APP1709        5185  6690.00      6690.00 [price, promo_price]                         Apple Smartwatch
#   APP1733        5185  8690.00      8690.00 [price, promo_price]                         Apple Smartwatch
#   LAC0222        5397  8199.00      5999.99 [price, promo_price]                   Data Storage Solutions
#   LAC0223        5397  9799.00      7899.99 [price, promo_price]                   Data Storage Solutions
#   PAC1555        1433  7865.18      6325.84 [price, promo_price]                   Data Storage Solutions
#   PAC1903        1433  7335.18      6165.84 [price, promo_price]                   Data Storage Solutions
# SYN0141-A        1298  3329.90      3193.06 [price, promo_price]              Refurbished & Used Products
#   PRO0029        5397  6842.99      5607.79              [price]                   Data Storage Solutions
# APP1374-A        1298  3169.00      2863.17 [price, promo_price]              Refurbished & Used Products
# APP1899-A        1298  3799.00      3360.81 [price, promo_price]              Refurbished & Used Products
# APP1873-A        1298  3179.00      2931.38 [price, promo_price]              Refurbished & Used Products
# APP1835-A        1298  2599.00      2373.85        [promo_price]              Refurbished & Used Products
#   REP0340        2062  1299.90      1299.90 [price, promo_price]             Device Services & Warranties
#   REP0379        2062  1699.90      1699.90 [price, promo_price]             Device Services & Warranties
#   REP0378        2062  1299.90      1299.90 [price, promo_price]             Device Services & Warranties
#   REP0392        2062  1499.90      1499.90 [price, promo_price]             Device Services & Warranties
#   WAC0234        1229   799.90       799.90 [price, promo_price]                            Pens & Stylus
#   AKI0029        5395   477.00       469.99        [promo_price]                        Cables & Adapters
# WAC0213-A        1298  3199.90      2770.39 [price, promo_price]              Refurbished & Used Products
# APP0660-A        1298  3490.00      2531.06 [price, promo_price]              Refurbished & Used Products
#   TAD0008        5404  1799.90      1799.90 [price, promo_price]                       Device Accessories
# APP1847-A        1298  2799.00      2405.59        [promo_price]              Refurbished & Used Products
# APP1810-A        1298  2699.00      2275.59        [promo_price]              Refurbished & Used Products
#   AP20245        1298  2939.00      2305.59 [price, promo_price]              Refurbished & Used Products
# OWC0191-4        1364  1383.96      1294.99        [promo_price]                              RAM Modules
# APP1369-A        1298  2749.00      2405.59        [promo_price]              Refurbished & Used Products
# APP2133-A        1298 14490.00     12748.61 [price, promo_price]              Refurbished & Used Products
#   COR0009        1325   641.99       639.99 [price, promo_price]                        Cables & Adapters
#   COR0012        1325   373.99       369.99        [promo_price]                        Cables & Adapters
#   APP2494        4259  2190.00      2190.00 [price, promo_price] Apple TV & Streaming Devices/Accessories
#   AP20351        1298  3949.00      2999.01 [price, promo_price]              Refurbished & Used Products
# IFX0120-A        5406   499.90       368.73 [price, promo_price]                     Repair Parts & Tools
#   FIT0052        5404  1599.86      1599.86 [price, promo_price]                       Device Accessories
#   DJI0022        5404  1499.00      1499.00 [price, promo_price]                       Device Accessories
#   PAC2476        1298  3709.00      2698.91 [price, promo_price]              Refurbished & Used Products
#   AP20442        1298  3559.00      2925.59 [price, promo_price]              Refurbished & Used Products
#   BEL0309        1325   349.93       349.93        [promo_price]                        Cables & Adapters
# TAD0002-A        5404  1799.90      1512.25 [price, promo_price]                       Device Accessories
# APP1000-A        1298  2609.00      2322.74        [promo_price]              Refurbished & Used Products
# APP2220-A        1298  2659.00      2402.05        [promo_price]              Refurbished & Used Products
# APP2225-A        1298  3079.00      2865.59 [price, promo_price]              Refurbished & Used Products
# APP2219-A        1298  2965.59      2606.92 [price, promo_price]              Refurbished & Used Products
# TRA0044-A        5397   710.90      5977.88        [promo_price]                   Data Storage Solutions
#   CAL0010        1334  2999.90      2999.90 [price, promo_price]                                  Network
#   GTE0130        5397  8169.99      6700.00 [price, promo_price]                   Data Storage Solutions
#   GTE0131        5397 10212.99      8300.00 [price, promo_price]                   Data Storage Solutions
#   GTE0136        5397  7836.99      6429.99 [price, promo_price]                   Data Storage Solutions
#   AP20447        1298  2839.00      2305.59        [promo_price]              Refurbished & Used Products
#   UBI0007        1334  3599.90      3599.90 [price, promo_price]                                  Network
#   DJI0026        5404  8490.00      8490.00 [price, promo_price]                       Device Accessories
#   DJI0025        5404  8490.00      8490.00 [price, promo_price]                       Device Accessories
#   LIN0014        1334  2999.90      2999.90 [price, promo_price]                                  Network
#   LIN0015        1334  4299.90      4299.90 [price, promo_price]                                  Network
# APP1904-A     unknown  3466.51      3466.51 [price, promo_price]                            Uncategorized
#   PAC0364     unknown  4090.99      3748.55 [price, promo_price]                            Uncategorized

# %%
# just drop the column again after we are done

products_df = products_df.drop(columns=['deviations'])
